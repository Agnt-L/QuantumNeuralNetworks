# %%
from qnn import build_qc_ent

qc = build_qc_ent()
qc.draw('mpl', justify='left')
# Out:
# k: 0, i: 0
# k: 1, i: 1
# k: 2, i: 2
# k: 3, i: 2, j: 4
# k: 4, i: 0
# k: 5, i: 1
# k: 6, i: 2
# k: 7, i: 2, j: 5
# k: 8, i: 0
# k: 9, i: 1
# k: 10, i: 2
# k: 11, i: 2, j: 6
# k: 12, i: 0
# k: 13, i: 1
# k: 14, i: 2
# k: 15, i: 2, j: 7
# k: 16, i: 0
# k: 17, i: 1
# k: 18, i: 2
# k: 19, i: 2, j: 5
# k: 20, i: 0
# k: 21, i: 1
# k: 22, i: 2
# k: 23, i: 2, j: 6
# k: 24, i: 0
# k: 25, i: 1
# k: 26, i: 2
# k: 27, i: 2, j: 7

# %%
from qnn import build_qc_ent_small_conv

qc = build_qc_ent_small_conv()
qc.draw('mpl', justify='left')
# Out:
# k: 0, i: 0
# k: 1, i: 1
# k: 2, i: 2
# k: 3, i: 2, j: 4
# k: 4, i: 2, j: 5
# k: 5, i: 2, j: 6
# k: 6, i: 2, j: 7
# k: 7, i: 0
# k: 8, i: 1
# k: 9, i: 2
# k: 10, i: 2, j: 4
# k: 11, i: 2, j: 5
# k: 12, i: 2, j: 6
# k: 13, i: 2, j: 7
# k: 14, i: 0
# k: 15, i: 1
# k: 16, i: 2
# k: 17, i: 2, j: 5
# k: 18, i: 2, j: 6
# k: 19, i: 2, j: 7
